# %%
D.<x> = PolynomialRing(QQ)
R.<x> = PolynomialRing(QQ)
CF=ComplexField(1000)
f = x^2+1;
f.roots()
S = PowerSeriesRing(QQ,'x', default_prec=300)
L=LaurentSeriesRing(QQ,'x', default_prec=300)
#S.<x,y>=PowerSeriesRing(QQ,default_prec=300)
# Using "R = PolynomialRing(QQ,'x')" produces an error.
# Yet using S as defined here is fine (see definition of Fraleigh4 below)
# But S = PowerSeriesRing(QQ,'x','y') also produces an error.
def pochhammer(x,n):
    return product ([x+k for k in [0..n-1]])
def cRaleigh2(alpha,beta,nu):
    pchhmrA = pochhammer(alpha,nu)
    pchhmrB = pochhammer(beta,nu)
    fnu=factorial(nu)
    answer = D(pchhmrA*pchhmrB/fnu^2)
    return answer
def term(alpha,beta,p):
    return D(1/(alpha + p) + 1/(beta + p) - 2/(1 + p))
def eRaleigh(alpha, beta, nu):
    return D(sum([term(alpha, beta, p) for p in [0..nu - 1]]))
def FstarRaleigh2(alpha,beta,u,terms):
    fsr = sum([cRaleigh2(alpha, beta, nu)*eRaleigh(alpha,beta,nu)*u^nu for nu in [1..terms]])
    return D(fsr)
def Fraleigh2(alpha,beta,u,terms): 
    return D(sum([cRaleigh2(alpha,beta,nu)*u^nu for nu in [0..terms]]))
def FstarRaleigh3(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fsr2 = FstarRaleigh2(alpha,beta,x,n)
    return D(fsr2)
def Fraleigh4(n,m,x):
    alpha = (1/2-1/m)/2
    beta = (1/2+1/m)/2
    fr2 = Fraleigh2(alpha,beta,x,n)
    return D(fr2)
def exNo3c(n,m):
    a1 = S(x)*exp(S(FstarRaleigh3(n,m,x)/Fraleigh4(n,m,x))).O(2*n)
    # S(x) instead of x in df of a1 to avoid an error message
    # after use of the stripQuotationMarks command below.
    a2 = S(a1).O(n+1)
    return a2 # applying S to argument of exp is key.
def J(n,m):
    exn = exNo3c(n+2,m)
    jnm = 1/exn.reverse()
    return jnm.O(n+1) # Jtest is faster than J, and they agree.
def normalJ(n,m):
    f = J(n,m)
    return f.truncate(n+1)
def Jcoefficient(n,m):
    f = J(n+2,m)
    f1 = f.truncate(n+1)
    f1=f1.list()
    f1=Set(f1)
    g1 = f.truncate(n)
    g1 = g1.list()
    g1 = set(g1)
    h = f1.difference(g1)
    h = h.list()
    return h[0]
def xjNew(n,m):
    def xjNewStep(n,m):
        f=J(n,m)
        fl=f.list()
        rt=0
        for i in [0..len(fl)-1]:
            rt=rt+fl[i]*x**i*(m**3*2**6)**i
        return rt
    return xjNewStep(n-1,m)
def j(n,m):return L(xjNew(n,m)/x)
def polynomialCoefficient(n,poly):
    return poly.list()[n]
def leadingCoefficient(polynomial):
    dg=polynomial.degree()
    return polynomialCoefficient(dg,polynomial)
def factorpairToFactor(factorpair):
    (monomial,exponent)=factorpair
    return monomial^exponent
def numericalfactor(polynomial):
    fp=polynomial.factor()
    lst=[factorpairToFactor(factorpair) for factorpair in fp]
    return polynomial/product(lst)
def firstfactor(polynomial):
    fp=polynomial.factor()
    fp=FiniteEnumeratedSet(fp)
    return factorpairToFactor(fp.first())
def lastfactor(polynomial):
    fp=polynomial.factor()
    fp=FiniteEnumeratedSet(fp)
    return factorpairToFactor(fp.last())
def reduced(polynomial):
    return numericalfactor(polynomial)*lastfactor(polynomial)
def stripQuotationMarks(string):
    var('x')
    return sage_eval(string,locals={'x':x})
def quotientFOvrG(f,g) : 
    return (f.maxima_methods().divide(g))[0]
def remainderFOvrG(f,g) : 
    return (f.maxima_methods().divide(g))[1]
def factor(polynomial):
    fp=polynomial.factor()
    return fp
def numberOfFactors(polynomial):
    fp=polynomial.factor()
    return len(fp)
def factorK(polynomial,k):
    fp=factor(h)
    return fp[k-1]
def factorList(polynomial):
    answer=[]
    nf=numberOfFactors(polynomial)
    for k in [1..nf]:
        answer=answer+[factorK(polynomial,k)]
    return answer
def polynomialExponentList(polynomial):
    pel=[]
    fp=polynomial.factor()
    lf=len(fp)
    for n in [0..lf-1]:
        part = fp[n]
        (base,exponent) = part
        pel=pel+[exponent]
    return pel
def polynomialFactorBaseList(polynomial):
    fbl=[]
    fp=polynomial.factor()
    lf=len(fp)
    for n in [0..lf-1]:
        part = fp[n]
        (base,exponent) = part
        fbl=fbl+[base]
    return fbl
def absoluteValue(x,precision):
    return N(sqrt(norm(x)),digits=precision)

# %%
absoluteValue(I,5)
# Out:
# 1.0000

# %%
data=[]
for m in [3..500]:
    if 10 in divisors(m):
        print(m)
    data=data+[[m,j(120,m)]]
import pickle
wfile = open('/Users/barrybrent/8mar21no6.txt','a')
s = pickle.dumps(str(data))
wfile.write(s)
wfile.close()
# printing snipped.

# %%
import pickle
rfile = open('/Users/barrybrent/8mar21no6.txt','r')
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
polydata=[]
import time
wfile = open('/Users/barrybrent/10mar21no8.txt','w') # interpolating polynomials
enoughfile=[]
for qpower in [0..120]:
    start = time.time()
    data=[]
    for k in [0..len(s)-1]:
        m = s[k][0]
        poly=x*s[k][1] 
# times x because, to use polynomialCoefficient, I need a polynomial; not a Laurent series
        cf=polynomialCoefficient(qpower,poly)
        data=data+[[m,cf]]
    rl=R.lagrange_polynomial(data)
    polydata=polydata+[[qpower-1,rl]] 
    finish = time.time()
    print([qpower,finish-start])
# -1 because I want to record the coefficients of the qpowers of the original Laurent series
t = pickle.dumps(str(polydata))
wfile.write(t)
wfile.close() # printing snipped.

# %%
import pickle
rfile = open('/Users/barrybrent/10mar21no8.txt','r')  # interpolating polynomials
rs=pickle.load(rfile)
rfile.close()
s=stripQuotationMarks(rs)
lengths=[]
discrepancies=[]
for k in [3..len(s)-1]:
    print "----------------------------------------------------------------------------------"
    points=[]
    n=s[k][0]
    radius= ln(n/ln(n))
    poly=R(s[k][1])
    pr=poly.roots(CC)
    lpr=len(pr)
    points=[]
    rootcount=0
    goodpoints=[]
    goodrootcount=0
    for j in [0..lpr-1]:
        rootpair=pr[j]
        (root,mult)=rootpair
        repart=real(root)
        impart=imaginary(root)
        root=[repart,impart]
        cplxroot=repart+I*impart
        points=points+[root]
        rootcount=rootcount+mult
        if absoluteValue(cplxroot,100)<radius:
            goodrootcount=goodrootcount+mult
    rootplot=list_plot(points,color='blue',size=10)
    circlepoints=[]
    for a in [0..199]:
        theta=(a/200)*(2*pi)
        point=[radius*cos(theta),radius*sin(theta)]
        circlepoints=circlepoints+[point]
    circle=list_plot(circlepoints,color='red')
    show(rootplot+circle)
    pd=poly.degree();rc=rootcount;grc=goodrootcount
    if pd>grc:discrepancies=discrepancies+[[n,pd-grc]]
    print "polynomial ",n," degree: ",pd," good-root count: ",grc,"  root count: ",rc
print "***************************************************************************************"
print " discrepancies: "
if len(discrepancies)==0:print "none"
if len(discrepancies)>0:print(discrepancies)
# Out:
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  2  degree:  9  good-root count:  7   root count:  9
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  3  degree:  12  good-root count:  8   root count:  12
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  4  degree:  15  good-root count:  9   root count:  15
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  5  degree:  18  good-root count:  10   root count:  18
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  6  degree:  21  good-root count:  11   root count:  21
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  7  degree:  24  good-root count:  12   root count:  24
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  8  degree:  27  good-root count:  13   root count:  27
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  9  degree:  30  good-root count:  14   root count:  30
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  10  degree:  33  good-root count:  15   root count:  33
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  11  degree:  36  good-root count:  16   root count:  36
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  12  degree:  39  good-root count:  17   root count:  39
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  13  degree:  42  good-root count:  18   root count:  42
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  14  degree:  45  good-root count:  19   root count:  45
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  15  degree:  48  good-root count:  20   root count:  48
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  16  degree:  51  good-root count:  21   root count:  51
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  17  degree:  54  good-root count:  22   root count:  54
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  18  degree:  57  good-root count:  23   root count:  57
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  19  degree:  60  good-root count:  24   root count:  60
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  20  degree:  63  good-root count:  25   root count:  63
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  21  degree:  66  good-root count:  26   root count:  66
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  22  degree:  69  good-root count:  27   root count:  69
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  23  degree:  72  good-root count:  28   root count:  72
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  24  degree:  75  good-root count:  31   root count:  75
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  25  degree:  78  good-root count:  32   root count:  78
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  26  degree:  81  good-root count:  33   root count:  81
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  27  degree:  84  good-root count:  34   root count:  84
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  28  degree:  87  good-root count:  39   root count:  87
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  29  degree:  90  good-root count:  40   root count:  90
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  30  degree:  93  good-root count:  41   root count:  93
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  31  degree:  96  good-root count:  42   root count:  96
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  32  degree:  99  good-root count:  43   root count:  99
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  33  degree:  102  good-root count:  44   root count:  102
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  34  degree:  105  good-root count:  45   root count:  105
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  35  degree:  108  good-root count:  46   root count:  108
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  94  degree:  285  good-root count:  139   root count:  285
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  95  degree:  288  good-root count:  140   root count:  288
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  96  degree:  291  good-root count:  141   root count:  291
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  97  degree:  294  good-root count:  142   root count:  294
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  98  degree:  297  good-root count:  143   root count:  297
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  99  degree:  300  good-root count:  144   root count:  300
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  100  degree:  303  good-root count:  149   root count:  303
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  101  degree:  306  good-root count:  150   root count:  306
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  102  degree:  309  good-root count:  151   root count:  309
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  103  degree:  312  good-root count:  152   root count:  312
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  104  degree:  315  good-root count:  153   root count:  315
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  105  degree:  318  good-root count:  158   root count:  318
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  106  degree:  321  good-root count:  159   root count:  321
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  107  degree:  324  good-root count:  160   root count:  324
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  108  degree:  327  good-root count:  161   root count:  327
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  109  degree:  330  good-root count:  162   root count:  330
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  110  degree:  333  good-root count:  163   root count:  333
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  111  degree:  336  good-root count:  164   root count:  336
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  112  degree:  339  good-root count:  165   root count:  339
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  113  degree:  342  good-root count:  170   root count:  342
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  114  degree:  345  good-root count:  175   root count:  345
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  115  degree:  348  good-root count:  174   root count:  348
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  116  degree:  351  good-root count:  173   root count:  351
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  117  degree:  354  good-root count:  180   root count:  354
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  118  degree:  357  good-root count:  181   root count:  357
# ----------------------------------------------------------------------------------
# Graphics object consisting of 2 graphics primitives
# polynomial  119  degree:  360  good-root count:  184   root count:  360
# ***************************************************************************************
#  discrepancies:
# [[2, 2], [3, 4], [4, 6], [5, 8], [6, 10], [7, 12], [8, 14], [9, 16], [10, 18], [11, 20], [12, 22], [13, 24], [14, 26], [15, 28], [16, 30], [17, 32], [18, 34], [19, 36], [20, 38], [21, 40], [22, 42], [23, 44], [24, 44], [25, 46], [26, 48], [27, 50], [28, 48], [29, 50], [30, 52], [31, 54], [32, 56], [33, 58], [34, 60], [35, 62], [36, 64], [37, 66], [38, 68], [39, 66], [40, 68], [41, 70], [42, 72], [43, 74], [44, 76], [45, 78], [46, 80], [47, 82], [48, 80], [49, 82], [50, 84], [51, 86], [52, 88], [53, 90], [54, 92], [55, 94], [56, 92], [57, 94], [58, 96], [59, 98], [60, 100], [61, 102], [62, 104], [63, 106], [64, 104], [65, 106], [66, 108], [67, 110], [68, 112], [69, 114], [70, 116], [71, 118], [72, 116], [73, 118], [74, 120], [75, 122], [76, 124], [77, 126], [78, 128], [79, 126], [80, 128], [81, 130], [82, 132], [83, 134], [84, 136], [85, 138], [86, 136], [87, 138], [88, 140], [89, 142], [90, 144], [91, 144], [92, 146], [93, 144], [94, 146], [95, 148], [96, 150], [97, 152], [98, 154], [99, 156], [100, 154], [101, 156], [102, 158], [103, 160], [104, 162], [105, 160], [106, 162], [107, 164], [108, 166], [109, 168], [110, 170], [111, 172], [112, 174], [113, 172], [114, 170], [115, 174], [116, 178], [117, 174], [118, 176], [119, 176]]
